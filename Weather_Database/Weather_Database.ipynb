# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 769

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=369f3a23d966efdf0f77a6ed102e4106

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | los llanos de aridane
# Processing Record 4 of Set 1 | sauda
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 1 | la paz
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | clyde river
# Processing Record 13 of Set 1 | kruisfontein
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | bulawayo
# Processing Record 16 of Set 1 | quelimane
# Processing Record 17 of Set 1 | belmonte
# Processing Record 18 of Set 1 | nesterov
# Processing Record 19 of Set 1 | nizhneudinsk
# Processing Record 20 of Set 1 | lagoa
# Processing Record 21 of Set 1 | sitka
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | awjilah
# Processing Record 24 of Set 1 | mount gambier
# Processing Record 25 of Set 1 | xuddur
# Processing Record 26 of Set 1 | vagay
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | umm kaddadah
# Processing Record 30 of Set 1 | port shepstone
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | kahului
# Processing Record 33 of Set 1 | kodiak
# Processing Record 34 of Set 1 | samarai
# Processing Record 35 of Set 1 | soanierana ivongo
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | fairbanks
# Processing Record 38 of Set 1 | tuy hoa
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | mecca
# Processing Record 42 of Set 1 | klaksvik
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | palana
# Processing Record 47 of Set 1 | yulara
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | guapi
# Processing Record 2 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 2 | manakara
# Processing Record 4 of Set 2 | khatanga
# Processing Record 5 of Set 2 | marquette
# Processing Record 6 of Set 2 | saldanha
# Processing Record 7 of Set 2 | kavieng
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | massaguet
# Processing Record 13 of Set 2 | baboua
# City not found. Skipping...
# Processing Record 14 of Set 2 | jimeta
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | saint george
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | lebu
# Processing Record 19 of Set 2 | tomigusuku
# Processing Record 20 of Set 2 | mateus leme
# Processing Record 21 of Set 2 | broome
# Processing Record 22 of Set 2 | yumen
# Processing Record 23 of Set 2 | airai
# Processing Record 24 of Set 2 | mehamn
# Processing Record 25 of Set 2 | nemuro
# Processing Record 26 of Set 2 | butaritari
# Processing Record 27 of Set 2 | mar del plata
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | kenai
# Processing Record 31 of Set 2 | assela
# City not found. Skipping...
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 34 of Set 2 | karratha
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | ambilobe
# Processing Record 37 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 2 | katobu
# Processing Record 39 of Set 2 | praia da vitoria
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | daru
# Processing Record 44 of Set 2 | tiksi
# Processing Record 45 of Set 2 | tsalka
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | arman
# Processing Record 50 of Set 2 | hambantota
# Processing Record 1 of Set 3 | busselton
# Processing Record 2 of Set 3 | arraial do cabo
# Processing Record 3 of Set 3 | salinas
# Processing Record 4 of Set 3 | dalbandin
# Processing Record 5 of Set 3 | verkhoyansk
# Processing Record 6 of Set 3 | touros
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | vaovai
# City not found. Skipping...
# Processing Record 9 of Set 3 | nanortalik
# Processing Record 10 of Set 3 | aklavik
# Processing Record 11 of Set 3 | puerto ayora
# Processing Record 12 of Set 3 | kaitangata
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | deputatskiy
# Processing Record 15 of Set 3 | usinsk
# Processing Record 16 of Set 3 | tingrela
# City not found. Skipping...
# Processing Record 17 of Set 3 | pakxan
# Processing Record 18 of Set 3 | gornopravdinsk
# Processing Record 19 of Set 3 | vrangel
# Processing Record 20 of Set 3 | bethel
# Processing Record 21 of Set 3 | clinton
# Processing Record 22 of Set 3 | katsuura
# Processing Record 23 of Set 3 | coahuayana
# Processing Record 24 of Set 3 | san lorenzo
# Processing Record 25 of Set 3 | maarianhamina
# Processing Record 26 of Set 3 | cidreira
# Processing Record 27 of Set 3 | yeppoon
# Processing Record 28 of Set 3 | craig
# Processing Record 29 of Set 3 | taoudenni
# Processing Record 30 of Set 3 | anchorage
# Processing Record 31 of Set 3 | atuona
# Processing Record 32 of Set 3 | bereda
# Processing Record 33 of Set 3 | itarema
# Processing Record 34 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 3 | ambunti
# Processing Record 36 of Set 3 | nome
# Processing Record 37 of Set 3 | den helder
# Processing Record 38 of Set 3 | bundaberg
# Processing Record 39 of Set 3 | cherdyn
# Processing Record 40 of Set 3 | kimbe
# Processing Record 41 of Set 3 | matagami
# Processing Record 42 of Set 3 | bluff
# Processing Record 43 of Set 3 | mananjary
# Processing Record 44 of Set 3 | taphan hin
# Processing Record 45 of Set 3 | hay river
# Processing Record 46 of Set 3 | tabou
# Processing Record 47 of Set 3 | itaituba
# Processing Record 48 of Set 3 | hilo
# Processing Record 49 of Set 3 | merrill
# Processing Record 50 of Set 3 | cherskiy
# Processing Record 1 of Set 4 | marinette
# Processing Record 2 of Set 4 | esmeraldas
# Processing Record 3 of Set 4 | paso de carrasco
# Processing Record 4 of Set 4 | norman wells
# Processing Record 5 of Set 4 | san quintin
# Processing Record 6 of Set 4 | poum
# Processing Record 7 of Set 4 | port macquarie
# Processing Record 8 of Set 4 | atar
# Processing Record 9 of Set 4 | tautira
# Processing Record 10 of Set 4 | biltine
# Processing Record 11 of Set 4 | juigalpa
# Processing Record 12 of Set 4 | erice
# Processing Record 13 of Set 4 | zhigalovo
# Processing Record 14 of Set 4 | camacha
# Processing Record 15 of Set 4 | lorengau
# Processing Record 16 of Set 4 | scottsbluff
# Processing Record 17 of Set 4 | esperance
# Processing Record 18 of Set 4 | lata
# Processing Record 19 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 4 | berlevag
# Processing Record 21 of Set 4 | caravelas
# Processing Record 22 of Set 4 | male
# Processing Record 23 of Set 4 | guayanilla
# Processing Record 24 of Set 4 | areka
# Processing Record 25 of Set 4 | bathsheba
# Processing Record 26 of Set 4 | constitucion
# Processing Record 27 of Set 4 | ancud
# Processing Record 28 of Set 4 | fasa
# Processing Record 29 of Set 4 | torbay
# Processing Record 30 of Set 4 | altay
# Processing Record 31 of Set 4 | baker city
# Processing Record 32 of Set 4 | pisco
# Processing Record 33 of Set 4 | port-cartier
# Processing Record 34 of Set 4 | husavik
# Processing Record 35 of Set 4 | tairua
# Processing Record 36 of Set 4 | gravdal
# Processing Record 37 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 38 of Set 4 | saint-joseph
# Processing Record 39 of Set 4 | aksu
# Processing Record 40 of Set 4 | brawley
# Processing Record 41 of Set 4 | coron
# Processing Record 42 of Set 4 | chumikan
# Processing Record 43 of Set 4 | dvinskoy
# Processing Record 44 of Set 4 | jalu
# Processing Record 45 of Set 4 | havoysund
# Processing Record 46 of Set 4 | ahipara
# Processing Record 47 of Set 4 | manokwari
# Processing Record 48 of Set 4 | avarua
# Processing Record 49 of Set 4 | qaanaaq
# Processing Record 50 of Set 4 | matara
# Processing Record 1 of Set 5 | yishui
# Processing Record 2 of Set 5 | flin flon
# Processing Record 3 of Set 5 | rossland
# Processing Record 4 of Set 5 | zuwarah
# Processing Record 5 of Set 5 | atambua
# Processing Record 6 of Set 5 | gayeri
# Processing Record 7 of Set 5 | keti bandar
# Processing Record 8 of Set 5 | chifeng
# Processing Record 9 of Set 5 | medina
# Processing Record 10 of Set 5 | batticaloa
# Processing Record 11 of Set 5 | bardiyah
# Processing Record 12 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 13 of Set 5 | tilichiki
# Processing Record 14 of Set 5 | yellowknife
# Processing Record 15 of Set 5 | faanui
# Processing Record 16 of Set 5 | saint-pierre
# Processing Record 17 of Set 5 | xining
# Processing Record 18 of Set 5 | glogow
# Processing Record 19 of Set 5 | half moon bay
# Processing Record 20 of Set 5 | venice
# Processing Record 21 of Set 5 | dingle
# Processing Record 22 of Set 5 | smithers
# Processing Record 23 of Set 5 | east london
# Processing Record 24 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 5 | moose factory
# Processing Record 26 of Set 5 | grand gaube
# Processing Record 27 of Set 5 | guiong
# Processing Record 28 of Set 5 | diamantina
# Processing Record 29 of Set 5 | koumac
# Processing Record 30 of Set 5 | korla
# Processing Record 31 of Set 5 | karangasem
# Processing Record 32 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 5 | manjacaze
# Processing Record 34 of Set 5 | barabai
# Processing Record 35 of Set 5 | luderitz
# Processing Record 36 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 5 | tyubuk
# Processing Record 39 of Set 5 | tabuk
# Processing Record 40 of Set 5 | alice springs
# Processing Record 41 of Set 5 | hithadhoo
# Processing Record 42 of Set 5 | kutum
# Processing Record 43 of Set 5 | waipawa
# Processing Record 44 of Set 5 | pizarro
# Processing Record 45 of Set 5 | maniitsoq
# Processing Record 46 of Set 5 | apatou
# Processing Record 47 of Set 5 | altoona
# Processing Record 48 of Set 5 | alofi
# Processing Record 49 of Set 5 | chapais
# Processing Record 50 of Set 5 | kaeo
# Processing Record 1 of Set 6 | aswan
# Processing Record 2 of Set 6 | kalikino
# Processing Record 3 of Set 6 | evans
# Processing Record 4 of Set 6 | thinadhoo
# Processing Record 5 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 6 | inhambane
# Processing Record 7 of Set 6 | puerto quijarro
# Processing Record 8 of Set 6 | burnie
# Processing Record 9 of Set 6 | xichang
# Processing Record 10 of Set 6 | cabo san lucas
# Processing Record 11 of Set 6 | tura
# Processing Record 12 of Set 6 | zamora
# Processing Record 13 of Set 6 | manicore
# Processing Record 14 of Set 6 | pangnirtung
# Processing Record 15 of Set 6 | nuevo progreso
# Processing Record 16 of Set 6 | victoria
# Processing Record 17 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 18 of Set 6 | souillac
# Processing Record 19 of Set 6 | emmett
# Processing Record 20 of Set 6 | syasstroy
# Processing Record 21 of Set 6 | bambous virieux
# Processing Record 22 of Set 6 | isla vista
# Processing Record 23 of Set 6 | mamallapuram
# Processing Record 24 of Set 6 | san patricio
# Processing Record 25 of Set 6 | siilinjarvi
# Processing Record 26 of Set 6 | pokhara
# Processing Record 27 of Set 6 | cedar city
# Processing Record 28 of Set 6 | vardo
# Processing Record 29 of Set 6 | axim
# Processing Record 30 of Set 6 | kathu
# Processing Record 31 of Set 6 | marabba
# Processing Record 32 of Set 6 | okha
# Processing Record 33 of Set 6 | severo-kurilsk
# Processing Record 34 of Set 6 | topolevo
# Processing Record 35 of Set 6 | oskarshamn
# Processing Record 36 of Set 6 | talavera
# Processing Record 37 of Set 6 | ban chang
# Processing Record 38 of Set 6 | cabral
# Processing Record 39 of Set 6 | rawson
# Processing Record 40 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 6 | padang
# Processing Record 42 of Set 6 | quatre cocos
# Processing Record 43 of Set 6 | kudahuvadhoo
# Processing Record 44 of Set 6 | shihezi
# Processing Record 45 of Set 6 | australind
# Processing Record 46 of Set 6 | steamboat springs
# Processing Record 47 of Set 6 | fortuna
# Processing Record 48 of Set 6 | vestmannaeyjar
# Processing Record 49 of Set 6 | ola
# Processing Record 50 of Set 6 | kieta
# Processing Record 1 of Set 7 | takoradi
# Processing Record 2 of Set 7 | jibuti
# Processing Record 3 of Set 7 | dois vizinhos
# Processing Record 4 of Set 7 | ostrovnoy
# Processing Record 5 of Set 7 | port hedland
# Processing Record 6 of Set 7 | dunedin
# Processing Record 7 of Set 7 | la ronge
# Processing Record 8 of Set 7 | kawardha
# Processing Record 9 of Set 7 | pevek
# Processing Record 10 of Set 7 | sheridan
# Processing Record 11 of Set 7 | honningsvag
# Processing Record 12 of Set 7 | kargasok
# Processing Record 13 of Set 7 | virginia beach
# Processing Record 14 of Set 7 | davila
# Processing Record 15 of Set 7 | codrington
# Processing Record 16 of Set 7 | egvekinot
# Processing Record 17 of Set 7 | turka
# Processing Record 18 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 19 of Set 7 | concepcion del oro
# Processing Record 20 of Set 7 | aldan
# Processing Record 21 of Set 7 | boysun
# Processing Record 22 of Set 7 | necochea
# Processing Record 23 of Set 7 | talnakh
# Processing Record 24 of Set 7 | wuwei
# Processing Record 25 of Set 7 | itoman
# Processing Record 26 of Set 7 | saint-francois
# Processing Record 27 of Set 7 | autazes
# Processing Record 28 of Set 7 | acapulco
# Processing Record 29 of Set 7 | rognan
# Processing Record 30 of Set 7 | gizo
# Processing Record 31 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 7 | richards bay
# Processing Record 33 of Set 7 | rtishchevo
# Processing Record 34 of Set 7 | karpushikha
# Processing Record 35 of Set 7 | ishigaki
# Processing Record 36 of Set 7 | shache
# Processing Record 37 of Set 7 | hualmay
# Processing Record 38 of Set 7 | geraldton
# Processing Record 39 of Set 7 | am timan
# Processing Record 40 of Set 7 | watertown
# Processing Record 41 of Set 7 | iqaluit
# Processing Record 42 of Set 7 | kavaratti
# Processing Record 43 of Set 7 | srednekolymsk
# Processing Record 44 of Set 7 | ca mau
# Processing Record 45 of Set 7 | ipixuna
# Processing Record 46 of Set 7 | coos bay
# Processing Record 47 of Set 7 | zarichne
# Processing Record 48 of Set 7 | bandarbeyla
# Processing Record 49 of Set 7 | teguise
# Processing Record 50 of Set 7 | shadrinsk
# Processing Record 1 of Set 8 | itacare
# Processing Record 2 of Set 8 | ormara
# Processing Record 3 of Set 8 | linhai
# Processing Record 4 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 5 of Set 8 | makung
# City not found. Skipping...
# Processing Record 6 of Set 8 | waingapu
# Processing Record 7 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 8 | zihuatanejo
# Processing Record 9 of Set 8 | chiclana
# Processing Record 10 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 8 | maneadero
# Processing Record 12 of Set 8 | kalomo
# City not found. Skipping...
# Processing Record 13 of Set 8 | omboue
# Processing Record 14 of Set 8 | sagone
# Processing Record 15 of Set 8 | satipo
# Processing Record 16 of Set 8 | penzance
# Processing Record 17 of Set 8 | tongzi
# Processing Record 18 of Set 8 | sao francisco de assis
# Processing Record 19 of Set 8 | ganta
# Processing Record 20 of Set 8 | villazon
# Processing Record 21 of Set 8 | ostersund
# Processing Record 22 of Set 8 | plakhtiyivka
# Processing Record 23 of Set 8 | mogadishu
# Processing Record 24 of Set 8 | ornskoldsvik
# Processing Record 25 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 8 | meulaboh
# Processing Record 27 of Set 8 | kismayo
# Processing Record 28 of Set 8 | verkhnevilyuysk
# Processing Record 29 of Set 8 | beterou
# Processing Record 30 of Set 8 | wichita falls
# Processing Record 31 of Set 8 | vredendal
# Processing Record 32 of Set 8 | lavrentiya
# Processing Record 33 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 34 of Set 8 | krasnoarmeysk
# Processing Record 35 of Set 8 | isangel
# Processing Record 36 of Set 8 | namibe
# Processing Record 37 of Set 8 | mapiri
# Processing Record 38 of Set 8 | tokur
# Processing Record 39 of Set 8 | goderich
# Processing Record 40 of Set 8 | zhezkazgan
# Processing Record 41 of Set 8 | kalmunai
# Processing Record 42 of Set 8 | seoul
# Processing Record 43 of Set 8 | mahon
# Processing Record 44 of Set 8 | marzuq
# Processing Record 45 of Set 8 | marsaxlokk
# Processing Record 46 of Set 8 | potgietersrus
# City not found. Skipping...
# Processing Record 47 of Set 8 | malanje
# Processing Record 48 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 8 | banon
# Processing Record 50 of Set 8 | ginda
# Processing Record 1 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 2 of Set 9 | te anau
# Processing Record 3 of Set 9 | galle
# Processing Record 4 of Set 9 | luanda
# Processing Record 5 of Set 9 | pingzhuang
# Processing Record 6 of Set 9 | sibolga
# Processing Record 7 of Set 9 | baykit
# Processing Record 8 of Set 9 | cabedelo
# Processing Record 9 of Set 9 | nelson bay
# Processing Record 10 of Set 9 | lima
# Processing Record 11 of Set 9 | semey
# Processing Record 12 of Set 9 | mount isa
# Processing Record 13 of Set 9 | nuuk
# Processing Record 14 of Set 9 | mayumba
# Processing Record 15 of Set 9 | bodden town
# Processing Record 16 of Set 9 | paamiut
# Processing Record 17 of Set 9 | harper
# Processing Record 18 of Set 9 | papasquiaro
# City not found. Skipping...
# Processing Record 19 of Set 9 | cayenne
# Processing Record 20 of Set 9 | elat
# Processing Record 21 of Set 9 | ofaqim
# Processing Record 22 of Set 9 | gafanha da encarnacao
# Processing Record 23 of Set 9 | sampit
# Processing Record 24 of Set 9 | saint anthony
# Processing Record 25 of Set 9 | chadan
# Processing Record 26 of Set 9 | sao felix do xingu
# Processing Record 27 of Set 9 | sao joao da barra
# Processing Record 28 of Set 9 | hede
# Processing Record 29 of Set 9 | maceio
# Processing Record 30 of Set 9 | kokopo
# Processing Record 31 of Set 9 | provideniya
# Processing Record 32 of Set 9 | bahia blanca
# Processing Record 33 of Set 9 | karlskrona
# Processing Record 34 of Set 9 | massa marittima
# Processing Record 35 of Set 9 | nishihara
# Processing Record 36 of Set 9 | benjamin hill
# Processing Record 37 of Set 9 | port-gentil
# Processing Record 38 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 39 of Set 9 | yuryuzan
# Processing Record 40 of Set 9 | port augusta
# Processing Record 41 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 9 | jumla
# Processing Record 44 of Set 9 | sumbe
# Processing Record 45 of Set 9 | singaparna
# Processing Record 46 of Set 9 | hasaki
# Processing Record 47 of Set 9 | faya
# Processing Record 48 of Set 9 | colares
# Processing Record 49 of Set 9 | awbari
# Processing Record 50 of Set 9 | arlit
# Processing Record 1 of Set 10 | guerrero negro
# Processing Record 2 of Set 10 | mackay
# Processing Record 3 of Set 10 | san luis potosi
# Processing Record 4 of Set 10 | komsomolskiy
# Processing Record 5 of Set 10 | maumere
# Processing Record 6 of Set 10 | leningradskiy
# Processing Record 7 of Set 10 | kurmanayevka
# Processing Record 8 of Set 10 | ballina
# Processing Record 9 of Set 10 | topdac
# Processing Record 10 of Set 10 | arawa
# Processing Record 11 of Set 10 | dehui
# Processing Record 12 of Set 10 | matamoros
# Processing Record 13 of Set 10 | dunda
# Processing Record 14 of Set 10 | sesheke
# Processing Record 15 of Set 10 | khani
# Processing Record 16 of Set 10 | humaita
# Processing Record 17 of Set 10 | cortez
# Processing Record 18 of Set 10 | solnechnyy
# Processing Record 19 of Set 10 | challans
# Processing Record 20 of Set 10 | palmer
# Processing Record 21 of Set 10 | westport
# Processing Record 22 of Set 10 | vanersborg
# Processing Record 23 of Set 10 | tottori
# Processing Record 24 of Set 10 | kushiro
# Processing Record 25 of Set 10 | salalah
# Processing Record 26 of Set 10 | zhangye
# Processing Record 27 of Set 10 | muscat
# Processing Record 28 of Set 10 | asau
# Processing Record 29 of Set 10 | merauke
# Processing Record 30 of Set 10 | bedesa
# Processing Record 31 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 10 | malatya
# Processing Record 33 of Set 10 | lasa
# Processing Record 34 of Set 10 | nowa ruda
# Processing Record 35 of Set 10 | luxor
# Processing Record 36 of Set 10 | itupiranga
# Processing Record 37 of Set 10 | vila
# Processing Record 38 of Set 10 | sambava
# Processing Record 39 of Set 10 | chany
# Processing Record 40 of Set 10 | crossville
# Processing Record 41 of Set 10 | dehri
# Processing Record 42 of Set 10 | grinnell
# Processing Record 43 of Set 10 | annau
# Processing Record 44 of Set 10 | buluang
# Processing Record 45 of Set 10 | bac lieu
# Processing Record 46 of Set 10 | kaka
# Processing Record 47 of Set 10 | acari
# Processing Record 48 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 49 of Set 10 | kloulklubed
# Processing Record 50 of Set 10 | hanzhong
# Processing Record 1 of Set 11 | kytmanovo
# Processing Record 2 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 11 | rio grande
# Processing Record 4 of Set 11 | comarapa
# Processing Record 5 of Set 11 | yeletskiy
# City not found. Skipping...
# Processing Record 6 of Set 11 | tsuyama
# Processing Record 7 of Set 11 | nantucket
# Processing Record 8 of Set 11 | ekhabi
# Processing Record 9 of Set 11 | ati
# Processing Record 10 of Set 11 | port moresby
# Processing Record 11 of Set 11 | alta floresta
# Processing Record 12 of Set 11 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 13 of Set 11 | nikolsk
# Processing Record 14 of Set 11 | kourou
# Processing Record 15 of Set 11 | qaqortoq
# Processing Record 16 of Set 11 | yar-sale
# Processing Record 17 of Set 11 | traverse city
# Processing Record 18 of Set 11 | iwanai
# Processing Record 19 of Set 11 | agirish
# Processing Record 20 of Set 11 | omsukchan
# Processing Record 21 of Set 11 | ranong
# Processing Record 22 of Set 11 | port blair
# Processing Record 23 of Set 11 | upernavik
# Processing Record 24 of Set 11 | tadine
# Processing Record 25 of Set 11 | looc
# Processing Record 26 of Set 11 | rebrikha
# Processing Record 27 of Set 11 | kuching
# Processing Record 28 of Set 11 | taltal
# Processing Record 29 of Set 11 | keuruu
# Processing Record 30 of Set 11 | port ellen
# City not found. Skipping...
# Processing Record 31 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 11 | piedade
# Processing Record 33 of Set 11 | khuzhir
# Processing Record 34 of Set 11 | narsaq
# Processing Record 35 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 36 of Set 11 | shenkursk
# Processing Record 37 of Set 11 | mirnyy
# Processing Record 38 of Set 11 | santa isabel do rio negro
# Processing Record 39 of Set 11 | yambio
# Processing Record 40 of Set 11 | jutai
# Processing Record 41 of Set 11 | gushikawa
# Processing Record 42 of Set 11 | gilgit
# Processing Record 43 of Set 11 | udachnyy
# Processing Record 44 of Set 11 | vanavara
# Processing Record 45 of Set 11 | bondoukou
# Processing Record 46 of Set 11 | mwinilunga
# Processing Record 47 of Set 11 | sao sepe
# Processing Record 48 of Set 11 | cairns
# Processing Record 49 of Set 11 | dragoman
# Processing Record 50 of Set 11 | hamilton
# Processing Record 1 of Set 12 | beringovskiy
# Processing Record 2 of Set 12 | hoganas
# Processing Record 3 of Set 12 | sistranda
# Processing Record 4 of Set 12 | oranjemund
# Processing Record 5 of Set 12 | bilma
# Processing Record 6 of Set 12 | burgersdorp
# Processing Record 7 of Set 12 | orlik
# Processing Record 8 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 9 of Set 12 | timra
# Processing Record 10 of Set 12 | antofagasta
# Processing Record 11 of Set 12 | imbituba
# Processing Record 12 of Set 12 | bonthe
# Processing Record 13 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 12 | balaipungut
# Processing Record 15 of Set 12 | ikovka
# Processing Record 16 of Set 12 | hobyo
# Processing Record 17 of Set 12 | san juan
# Processing Record 18 of Set 12 | ust-maya
# Processing Record 19 of Set 12 | villarrica
# Processing Record 20 of Set 12 | besikduzu
# Processing Record 21 of Set 12 | hami
# Processing Record 22 of Set 12 | bengkulu
# Processing Record 23 of Set 12 | trincomalee
# Processing Record 24 of Set 12 | norrtalje
# Processing Record 25 of Set 12 | mocuba
# Processing Record 26 of Set 12 | valparaiso
# Processing Record 27 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 28 of Set 12 | fram
# Processing Record 29 of Set 12 | ukiah
# Processing Record 30 of Set 12 | tigil
# Processing Record 31 of Set 12 | kabompo
# Processing Record 32 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 34 of Set 12 | xiongshi
# City not found. Skipping...
# Processing Record 35 of Set 12 | grindavik
# Processing Record 36 of Set 12 | san jose
# Processing Record 37 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 38 of Set 12 | kichera
# Processing Record 39 of Set 12 | kholmogory
# Processing Record 40 of Set 12 | yerbogachen
# Processing Record 41 of Set 12 | dwarka
# Processing Record 42 of Set 12 | andros town
# Processing Record 43 of Set 12 | paraiso
# Processing Record 44 of Set 12 | ayagoz
# Processing Record 45 of Set 12 | laguna
# Processing Record 46 of Set 12 | johi
# Processing Record 47 of Set 12 | kissidougou
# Processing Record 48 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 12 | havre-saint-pierre
# Processing Record 50 of Set 12 | progreso
# Processing Record 1 of Set 13 | vytegra
# Processing Record 2 of Set 13 | sombrio
# Processing Record 3 of Set 13 | cotonou
# Processing Record 4 of Set 13 | hirara
# Processing Record 5 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 6 of Set 13 | northam
# Processing Record 7 of Set 13 | bilibino
# Processing Record 8 of Set 13 | turukhansk
# Processing Record 9 of Set 13 | zheleznogorsk-ilimskiy
# Processing Record 10 of Set 13 | opuwo
# Processing Record 11 of Set 13 | zhigansk
# Processing Record 12 of Set 13 | esso
# Processing Record 13 of Set 13 | namatanai
# Processing Record 14 of Set 13 | changping
# Processing Record 15 of Set 13 | kinsale
# Processing Record 16 of Set 13 | mitu
# Processing Record 17 of Set 13 | boueni
# Processing Record 18 of Set 13 | miles city
# Processing Record 19 of Set 13 | boyolangu
# Processing Record 20 of Set 13 | praia
# Processing Record 21 of Set 13 | kropotkin
# Processing Record 22 of Set 13 | lincoln
# Processing Record 23 of Set 13 | moyale
# Processing Record 24 of Set 13 | svetlogorsk
# Processing Record 25 of Set 13 | vila velha
# Processing Record 26 of Set 13 | adrar
# Processing Record 27 of Set 13 | punto fijo
# Processing Record 28 of Set 13 | hokitika
# Processing Record 29 of Set 13 | schmallenberg
# Processing Record 30 of Set 13 | escanaba
# Processing Record 31 of Set 13 | hofn
# Processing Record 32 of Set 13 | behshahr
# Processing Record 33 of Set 13 | broceni
# Processing Record 34 of Set 13 | watrous
# Processing Record 35 of Set 13 | kyren
# Processing Record 36 of Set 13 | gorontalo
# Processing Record 37 of Set 13 | huarmey
# Processing Record 38 of Set 13 | kagadi
# Processing Record 39 of Set 13 | santa barbara
# Processing Record 40 of Set 13 | chardara
# Processing Record 41 of Set 13 | gualaquiza
# Processing Record 42 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 43 of Set 13 | tessalit
# Processing Record 44 of Set 13 | yarmouth
# Processing Record 45 of Set 13 | elk plain
# Processing Record 46 of Set 13 | oistins
# Processing Record 47 of Set 13 | fereydun kenar
# Processing Record 48 of Set 13 | severiano melo
# Processing Record 49 of Set 13 | castrillon
# Processing Record 50 of Set 13 | palauig
# Processing Record 1 of Set 14 | kachug
# Processing Record 2 of Set 14 | fort nelson
# Processing Record 3 of Set 14 | maragogi
# Processing Record 4 of Set 14 | sakakah
# Processing Record 5 of Set 14 | campbell river
# Processing Record 6 of Set 14 | saint-augustin
# Processing Record 7 of Set 14 | bratsk
# Processing Record 8 of Set 14 | ishim
# Processing Record 9 of Set 14 | belaya gora
# Processing Record 10 of Set 14 | high level
# Processing Record 11 of Set 14 | piacabucu
# Processing Record 12 of Set 14 | darhan
# Processing Record 13 of Set 14 | skjervoy
# Processing Record 14 of Set 14 | port lincoln
# Processing Record 15 of Set 14 | san cristobal
# Processing Record 16 of Set 14 | lokosovo
# Processing Record 17 of Set 14 | urucara
# Processing Record 18 of Set 14 | baruun-urt
# Processing Record 19 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 14 | edea
# Processing Record 21 of Set 14 | sandi
# Processing Record 22 of Set 14 | alyangula
# Processing Record 23 of Set 14 | ahuimanu
# Processing Record 24 of Set 14 | tuatapere
# Processing Record 25 of Set 14 | knysna
# Processing Record 26 of Set 14 | koygorodok
# Processing Record 27 of Set 14 | chojnice
# Processing Record 28 of Set 14 | okhotsk
# Processing Record 29 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 14 | benguela
# Processing Record 31 of Set 14 | pangkalanbuun
# Processing Record 32 of Set 14 | nanakuli
# Processing Record 33 of Set 14 | fukue
# Processing Record 34 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 14 | abaujszanto
# Processing Record 36 of Set 14 | beni mazar
# Processing Record 37 of Set 14 | russell
# Processing Record 38 of Set 14 | naantali
# Processing Record 39 of Set 14 | dumitra
# Processing Record 40 of Set 14 | rudbar
# Processing Record 41 of Set 14 | mehran
# Processing Record 42 of Set 14 | starosubkhangulovo
# Processing Record 43 of Set 14 | bukoba
# Processing Record 44 of Set 14 | pochutla
# Processing Record 45 of Set 14 | grand-santi
# Processing Record 46 of Set 14 | sinsheim
# Processing Record 47 of Set 14 | san angelo
# Processing Record 48 of Set 14 | la rioja
# Processing Record 49 of Set 14 | verkhnetulomskiy
# Processing Record 50 of Set 14 | makakilo city
# Processing Record 1 of Set 15 | tupik
# Processing Record 2 of Set 15 | murfreesboro
# Processing Record 3 of Set 15 | katherine
# Processing Record 4 of Set 15 | porto novo
# Processing Record 5 of Set 15 | riyadh
# Processing Record 6 of Set 15 | acarigua
# Processing Record 7 of Set 15 | dom pedrito
# Processing Record 8 of Set 15 | kargil
# Processing Record 9 of Set 15 | weymouth
# Processing Record 10 of Set 15 | racoviteni
# Processing Record 11 of Set 15 | chimoio
# Processing Record 12 of Set 15 | ambrolauri
# Processing Record 13 of Set 15 | slyudyanka
# Processing Record 14 of Set 15 | krasnogvardeyskiy
# Processing Record 15 of Set 15 | mogzon
# Processing Record 16 of Set 15 | elizabeth city
# Processing Record 17 of Set 15 | yaan
# Processing Record 18 of Set 15 | lithgow
# Processing Record 19 of Set 15 | chunoyar
# Processing Record 20 of Set 15 | panaba
# Processing Record 21 of Set 15 | limbazi
# Processing Record 22 of Set 15 | manzil salim
# Processing Record 23 of Set 15 | rapid valley
# Processing Record 24 of Set 15 | pyapon
# Processing Record 25 of Set 15 | paita
# Processing Record 26 of Set 15 | teya
# Processing Record 27 of Set 15 | coquimbo
# Processing Record 28 of Set 15 | thai binh
# Processing Record 29 of Set 15 | ossora
# Processing Record 30 of Set 15 | huoqiu
# Processing Record 31 of Set 15 | chaa-khol
# City not found. Skipping...
# Processing Record 32 of Set 15 | peleduy
# Processing Record 33 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 15 | manoel urbano
# Processing Record 35 of Set 15 | catuday
# Processing Record 36 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 37 of Set 15 | merida
# Processing Record 38 of Set 15 | parana
# Processing Record 39 of Set 15 | luganville
# Processing Record 40 of Set 15 | manggar
# Processing Record 41 of Set 15 | sorland
# Processing Record 42 of Set 15 | blagoyevo
# Processing Record 43 of Set 15 | auki
# Processing Record 44 of Set 15 | winnemucca
# Processing Record 45 of Set 15 | banda aceh
# Processing Record 46 of Set 15 | natal
# Processing Record 47 of Set 15 | techiman
# Processing Record 48 of Set 15 | ust-tsilma
# Processing Record 49 of Set 15 | shenavan
# Processing Record 50 of Set 15 | pyaozerskiy
# Processing Record 1 of Set 16 | araouane
# Processing Record 2 of Set 16 | ust-kalmanka
# Processing Record 3 of Set 16 | potosi
# Processing Record 4 of Set 16 | burica
# City not found. Skipping...
# Processing Record 5 of Set 16 | sinnamary
# Processing Record 6 of Set 16 | kannur
# Processing Record 7 of Set 16 | donegal
# Processing Record 8 of Set 16 | mirabad
# Processing Record 9 of Set 16 | namwala
# Processing Record 10 of Set 16 | aitape
# Processing Record 11 of Set 16 | portland
# Processing Record 12 of Set 16 | bucovat
# Processing Record 13 of Set 16 | madang
# Processing Record 14 of Set 16 | nanaimo
# Processing Record 15 of Set 16 | kiskunlachaza
# Processing Record 16 of Set 16 | saint-denis
# Processing Record 17 of Set 16 | ust-kuyga
# Processing Record 18 of Set 16 | scandicci
# Processing Record 19 of Set 16 | naze
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 705

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Rikitea -23.1203 -134.9692     74.70        80           8
# 1  Los Llanos De Aridane  28.6585  -17.9182     60.55        86          75
# 2                  Sauda  59.6506    6.3542     32.68        72           2
# 3              Jamestown  42.0970  -79.2353     36.99        76         100
# 4                 Albany  42.6001  -73.9662     38.88        61          26
# 5                 La Paz -16.5000  -68.1500     46.38        75          20
# 6             Chokurdakh  70.6333  147.9167    -24.65        99          60
# 7             Nikolskoye  59.7035   30.7861     22.91        87         100
# 8            Clyde River  70.4692  -68.5914    -15.47        80           1
# 9           Kruisfontein -34.0033   24.7314     60.89        77         100
#
#    Wind Speed Country Weather Description
# 0       14.29      PF           clear sky
# 1        5.75      ES       broken clouds
# 2        5.91      NO           clear sky
# 3       10.36      US     overcast clouds
# 4        1.99      US    scattered clouds
# 5        9.22      BO          few clouds
# 6        9.86      RU       broken clouds
# 7        8.39      RU     overcast clouds
# 8        4.50      CA           clear sky
# 9        2.44      ZA     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
ordering_column = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Weather Description"]

# Recreate the DataFrame by using the new column order
WeatherPy_Database = city_data_df[ordering_column]

# Display sample data
WeatherPy_Database
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0                  Rikitea      PF -23.1203 -134.9692     74.70        80
# 1    Los Llanos De Aridane      ES  28.6585  -17.9182     60.55        86
# 2                    Sauda      NO  59.6506    6.3542     32.68        72
# 3                Jamestown      US  42.0970  -79.2353     36.99        76
# 4                   Albany      US  42.6001  -73.9662     38.88        61
# ..                     ...     ...      ...       ...       ...       ...
# 700          Kiskunlachaza      HU  47.1884   19.0093     39.04        90
# 701            Saint-Denis      FR  48.9167    2.3333     37.18        87
# 702              Ust-Kuyga      RU  70.0167  135.6000     -9.00        98
# 703              Scandicci      IT  43.7542   11.1879     52.54        95
# 704                   Naze      JP  28.3667  129.4833     69.89        80
#
#      Cloudiness  Wind Speed Weather Description
# 0             8       14.29           clear sky
# 1            75        5.75       broken clouds
# 2             2        5.91           clear sky
# 3           100       10.36     overcast clouds
# 4            26        1.99    scattered clouds
# ..          ...         ...                 ...
# 700         100       10.22     overcast clouds
# 701         100       12.66     overcast clouds
# 702         100       10.11          light snow
# 703          75        4.61       broken clouds
# 704          81        4.72       broken clouds
#
# [705 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
WeatherPy_Database.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "World_Weather_Analysis/Weather_Database"

# Export the city_data DataFrame into a CSV file
WeatherPy_Database.to_csv('WeatherPy_Database.csv',index_label="City_ID")
